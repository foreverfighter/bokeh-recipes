# %%
import random

import pandas as pd
from bokeh.io.export import export_png
from bokeh.models import ColumnDataSource, Span, Label
from bokeh.models.formatters import NumeralTickFormatter
from bokeh.palettes import all_palettes, Accent8, Spectral4, Spectral6, Inferno3, Inferno6, Inferno7
from bokeh.plotting import figure, show, output_file, output_notebook

# %%
# Task: Take pasted and output lists
# Task: Take pasted and output dicts with the first column as keys

headers = True
pasted = """2017	2018
62500	50000
125000	100000
187500	150000"""


62,500.00	50,000.00
125,000.00	100,000.00
187,500.00	150,000.00
250,000.00	200,000.00
312,500.00	250,000.00
375,000.00	300,000.00
437,500.00	350,000.00
500,000.00	400,000.00
562,500.00	450,000.00

# %%
from helpers import *

# %%
import helpers

# %%
pasted = """2017	2018
62500	50000
125000	100000
187500	150000"""

# %%
helpers.to_lists
# Out:
# <function helpers.to_lists(pasted, categorical=False)>

# %%
helpers.to_lists(pasted)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-3104f9246a2b> in <module>()
# ----> 1 helpers.to_lists(pasted)
#
# ~/playground/bokeh-recipes/helpers.py in to_lists(pasted, categorical)
#       8     for line in lines:
#       9         pigs = line.split('\t')
# ---> 10         for i, value in enumerate(pigs):
#      11             try:
#      12                 if categorical[i]:
#
# NameError: name 'values' is not defined

# %%
to_lists(pasted)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-b51c1ee5d8f6> in <module>()
# ----> 1 to_lists(pasted)
#
# ~/playground/bokeh-recipes/helpers.py in to_lists(pasted, categorical)
#       8     for line in lines:
#       9         a = 0
# ---> 10     return lists
#      11
#      12
#
# NameError: name 'values' is not defined

# %%
for line in lines:
    values = line.split('\t')
    print(values)
# Out:
# ['2017', '2018']
# ['62500', '50000']
# ['125000', '100000']
# ['187500', '150000']

# %%
data = {'periods': ['Q1 17', 'Q2 17', 'Q3 17', 'Q4 17', 'Q1 18', 'Q2 18', 'Q3 18'],
        'gmv': [212210.22,249741.43,187860.90,3510028.06,258004.44,283408.59,403613.27],
        'colors': Spectral4 + Spectral4[:3]}
source = ColumnDataSource(data)
p = figure(
    x_range=data['periods'],
    title="GMV YOY QS", 
    plot_width=800, 
    plot_height=400, 
    toolbar_location=None, 
    tools="",
    y_axis_label='Total Gross Merchanise Value',    
    y_minor_ticks=None,
)

p.yaxis.formatter = NumeralTickFormatter(format="($ 0.00 a)")
p.axis.major_tick_line_color = None
p.axis.minor_tick_line_color = None
p.ygrid.grid_line_color = '#D8D8D8'
p.xgrid.grid_line_color = None

p.add_layout(Span(location=405,
                  location_units='screen',
                  dimension='height',
                  line_color='#B8B8B8'
            ))

p.add_layout(Label(x=180, y=300, x_units='screen', y_units='screen', text='2017', render_mode='css',
                   border_line_color=None,
                   background_fill_color=None,
                   background_fill_alpha=1.0))
p.add_layout(Label(x=550, y=300, x_units='screen', y_units='screen', text='2018', render_mode='css',
                   border_line_color=None,
                   background_fill_color=None,
                   background_fill_alpha=1.0))


p.vbar(x='periods', width=0.5, top='gmv', color='colors', source=source)
#     y_axis_location=,


# output_file("myBokeh.html") with this we can output to a new html file
output_notebook()
# export_png(p)
# export_png(p, 'gmv.png', height=600, width=900)

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="87c5c60c-a2a0-4712-8889-e8d3b2a26c8a">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="31df3e98-0c77-4197-a4dd-88421fea6fa7"></div>
# </div>

# %%
commands = ['Country','Name','Order By']
speeds = [2584,510,140]
p = figure(x_range=commands ,title="Usage of Artist filters", plot_width=600, plot_height=400, toolbar_location=None, tools="")
p.vbar(x=commands, width=0.5, top=speeds, color=Accent8[:3])

p.y_range.start = 0
p.xgrid.grid_line_color = None
p.yaxis.axis_label = "Instances"

output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="a79309d2-ad34-4a45-bbee-410871e7d498">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="7cbb9428-f5af-411b-9738-739fa09ffcd3"></div>
# </div>

# %%
categories = ['Singapore','China','Japan', 'Philippines', 'Indonesia', 'South Korea']
heights = [592, 257, 140, 121, 119, 110]
rdm_palette = random.choice(list(all_palettes.keys()))
p = figure(x_range=categories ,title="Artist filters by country", plot_width=600, plot_height=400, toolbar_location=None, tools="")
p.vbar(x=categories, width=0.5, top=heights, color=all_palettes[rdm_palette][len(categories)])
p.y_range.start = 0
p.xgrid.grid_line_color = None
p.yaxis.axis_label = "Instances"

output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="38506360-a6dc-422c-a7d6-96f5b89e519d">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="2a85453d-1272-4d62-8514-e8bcfe941c2d"></div>
# </div>

# %%
commands = ['medium:painting','artwork_style:abstract','medium:photography', 'medium:sculpture', 'medium:drawing', 'medium:mixed media', 'medium:illustration']
speeds = [12695, 7392, 6098, 5774, 5317, 5232, 5060]
p = figure(x_range=commands ,title="Most popular artwork filters", plot_width=900, plot_height=400, toolbar_location=None, tools="")
p.vbar(x=commands, width=0.5, top=speeds, color=Accent8[:7])
p.y_range.start = 0
p.xgrid.grid_line_color = None
p.yaxis.axis_label = "Instances"

output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="63dacfa8-b0d4-4682-9d7d-403f5cdc4ac8">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="692cb2f8-65c5-4495-87e7-e10ef6391ea9"></div>
# </div>

# %%
from bokeh.models import LabelSet, Label
from bokeh.plotting import figure

p = figure()
labels = LabelSet(x='weight', y='height', text='names', level='glyph',
              x_offset=5, y_offset=5, source=source, render_mode='canvas')
citation = Label(x=70, y=70, x_units='screen', y_units='screen',
                 text='Collected by Luke C. 2016-04-01', render_mode='css',
                 border_line_color='black', border_line_alpha=1.0,
                 background_fill_color='white', background_fill_alpha=1.0)
p.add_layout(labels)
p.add_layout(citation)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-a53b93cf4c07> in <module>()
#       4 p = figure()
#       5 labels = LabelSet(x='weight', y='height', text='names', level='glyph',
# ----> 6               x_offset=5, y_offset=5, source=source, render_mode='canvas')
#       7 citation = Label(x=70, y=70, x_units='screen', y_units='screen',
#       8                  text='Collected by Luke C. 2016-04-01', render_mode='css',
#
# NameError: name 'source' is not defined
